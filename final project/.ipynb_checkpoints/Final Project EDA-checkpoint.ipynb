# %%
# %matplotlib inline
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#import vpython

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_validate

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegressionCV

from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

# %%
in_orbit = pd.read_csv("data/space_track_objects_in_orbit.csv")
box_score = pd.read_csv("data/space_track_box_score.csv")
decayed = pd.read_csv("data/space_track_decayed_objects.csv")

in_orbit.head(10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-f8a304ac22e0> in <module>
# ----> 1 in_orbit = pd.read_csv("data/space_track_objects_in_orbit.csv")
#       2 box_score = pd.read_csv("data/space_track_box_score.csv")
#       3 decayed = pd.read_csv("data/space_track_decayed_objects.csv")
#       4
#       5 in_orbit.head(10)
#
# ...

# %%
box_score.head(10)

# %%
decayed.head(10)

# %%
quants = ['PERIOD', 'INCLINATION', 'APOGEE', 'PERIGEE']

#print(decayed.dtypes)
#sns.pairplot(decayed[np.append(quants,'')]);

display(decayed['DECAY'])

fig, ax = plt.subplots(1,2)

ax[0].scatter(decayed['PERIOD'], decayed['INCLINATION'])

ax[1].hist(decayed['COUNTRY'])#, decayed.groupby('COUNTRY').count())
